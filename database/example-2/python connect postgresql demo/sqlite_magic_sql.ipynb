# %%
# %load_ext sql

# %%
# %sql sqlite:///hr.db
# Out:
# 'Connected: @hr.db'

# %%
# %sql SELECT * FROM employees ORDER BY first_name
# Out:
#  * sqlite:///hr.db
# Done.
# [(121, 'Adam', 'Fripp', 8200),
#  (103, 'Alexander', 'Hunold', 9000),
#  (115, 'Alexander', 'Khoo', 3100),
#  (104, 'Bruce', 'Ernst', 6000),
#  (109, 'Daniel', 'Faviet', 9000),
#  (105, 'David', 'Austin', 4800),
#  (114, 'Den', 'Raphaely', 11000),
#  (107, 'Diana', 'Lorentz', 4200),
#  (118, 'Guy', 'Himuro', 2600),
#  (111, 'Ismael', 'Sciarra', 7700),
#  (110, 'John', 'Chen', 8200),
#  (112, 'Jose Manuel', 'Urman', 7800),
#  (125, 'Julia', 'Nayer', 3200),
#  (119, 'Karen', 'Colmenares', 2500),
#  (124, 'Kevin', 'Mourgos', 5800),
#  (102, 'Lex', 'De Haan', 17000),
#  (113, 'Luis', 'Popp', 6900),
#  (120, 'Matthew', 'Weiss', 8000),
#  (108, 'Nancy', 'Greenberg', 12008),
#  (101, 'Neena', 'Kochhar', 17000),
#  (122, 'Payam', 'Kaufling', 7900),
#  (123, 'Shanta', 'Vollman', 6500),
#  (116, 'Shelli', 'Baida', 2900),
#  (117, 'Sigal', 'Tobias', 2800),
#  (100, 'Steven', 'King', 24000),
#  (106, 'Valli', 'Pataballa', 4800)]

# %%
# %sql SELECT COUNT(*),SUM(salary),MAX(salary),MIN(salary),AVG(salary) FROM employees
# Out:
#  * sqlite:///hr.db
# Done.
# [(26, 202908, 24000, 2500, 7804.153846153846)]

# %%
# %sql SELECT employee_id, first_name, last_name, salary FROM employees ORDER BY first_name
# Out:
#  * sqlite:///hr.db
# Done.
# [(121, 'Adam', 'Fripp', 8200),
#  (103, 'Alexander', 'Hunold', 9000),
#  (115, 'Alexander', 'Khoo', 3100),
#  (104, 'Bruce', 'Ernst', 6000),
#  (109, 'Daniel', 'Faviet', 9000),
#  (105, 'David', 'Austin', 4800),
#  (114, 'Den', 'Raphaely', 11000),
#  (107, 'Diana', 'Lorentz', 4200),
#  (118, 'Guy', 'Himuro', 2600),
#  (111, 'Ismael', 'Sciarra', 7700),
#  (110, 'John', 'Chen', 8200),
#  (112, 'Jose Manuel', 'Urman', 7800),
#  (125, 'Julia', 'Nayer', 3200),
#  (119, 'Karen', 'Colmenares', 2500),
#  (124, 'Kevin', 'Mourgos', 5800),
#  (102, 'Lex', 'De Haan', 17000),
#  (113, 'Luis', 'Popp', 6900),
#  (120, 'Matthew', 'Weiss', 8000),
#  (108, 'Nancy', 'Greenberg', 12008),
#  (101, 'Neena', 'Kochhar', 17000),
#  (122, 'Payam', 'Kaufling', 7900),
#  (123, 'Shanta', 'Vollman', 6500),
#  (116, 'Shelli', 'Baida', 2900),
#  (117, 'Sigal', 'Tobias', 2800),
#  (100, 'Steven', 'King', 24000),
#  (106, 'Valli', 'Pataballa', 4800)]

# %%
data = %sql SELECT * FROM employees ORDER BY first_name
# Out:
#  * sqlite:///hr.db
# Done.

# %%
df = data.DataFrame()
df
# Out:
#     employee_id   first_name   last_name  salary
# 0           121         Adam       Fripp    8200
# 1           103    Alexander      Hunold    9000
# 2           115    Alexander        Khoo    3100
# 3           104        Bruce       Ernst    6000
# 4           109       Daniel      Faviet    9000
# 5           105        David      Austin    4800
# 6           114          Den    Raphaely   11000
# 7           107        Diana     Lorentz    4200
# 8           118          Guy      Himuro    2600
# 9           111       Ismael     Sciarra    7700
# 10          110         John        Chen    8200
# 11          112  Jose Manuel       Urman    7800
# 12          125        Julia       Nayer    3200
# 13          119        Karen  Colmenares    2500
# 14          124        Kevin     Mourgos    5800
# 15          102          Lex     De Haan   17000
# 16          113         Luis        Popp    6900
# 17          120      Matthew       Weiss    8000
# ...
